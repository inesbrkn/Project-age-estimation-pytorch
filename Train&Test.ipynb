# %%
import getpass

token = getpass.getpass("GitHub token: ")

repo_url = f"https://{token}@github.com/inesbrkn/Project-age-estimation-pytorch.git"

# !git clone {repo_url}
# Out:
# GitHub token: ··········
# Cloning into 'Project-age-estimation-pytorch'...
# remote: Enumerating objects: 25590, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 25590 (delta 66), reused 43 (delta 33), pack-reused 25386 (from 1)
# Receiving objects: 100% (25590/25590), 892.14 MiB | 10.90 MiB/s, done.
# Resolving deltas: 100% (2126/2126), done.
# Updating files: 100% (2517/2517), done.

# %%
# %cd Project-age-estimation-pytorch
# !git checkout InesB
# %cd Recent
# !ls
# Out:
# /content/Project-age-estimation-pytorch/Recent/Project-age-estimation-pytorch
# Updating files: 100% (25297/25297), done.
# Branch 'InesB' set up to track remote branch 'InesB' from 'origin'.
# Switched to a new branch 'InesB'
# /content/Project-age-estimation-pytorch/Recent/Project-age-estimation-pytorch/Recent
# dataset.py  defaults.py  demo.py  model.py  requirements.txt  test.py  train.py

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !pip install -r requirements.txt

# %% [markdown]
# à cause de la mémoire de collab jai mis batch_size à 80 et les coeurs à 2 ( changer dans defaults si vous voulez tester )

# %%
import numpy as np
print(np.__version__)

# !python train.py --data_dir ../appa-real-release --tensorboard tf_log
# Out:
# 2.0.2
# 2026-02-17 12:47:42.805576: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 12:47:42.925995: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 12:47:42.996346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771332463.084916   30773 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771332463.112574   30773 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Afficher le tensorboard pour analyse

# %%
# !tensorboard --logdir=tf_log

# %% [markdown]
# Maintenant on test dans checkpoint prenez le fichier avec le best mae à la section précedente lors de l'entrainement on a un retour pour savoir quel epoch est le meilleur prenez celui qui a un num epoch proch ( si le mae n'a pas changé ya pas de nouveau fichier dans le checkpoint c'est pour ça )

# %%
# !python test.py --data_dir ../appa-real-release --resume ./checkpoint/epoch029_0.02398_4.2032.pth
# Out:
# python3: can't open file '/content/test.py': [Errno 2] No such file or directory
